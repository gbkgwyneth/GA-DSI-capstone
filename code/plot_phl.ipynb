# %% [markdown]
# # <span style='color:#3b748a'>The trip data for Philly is TOO large to upload to GitHub.</span>

# %% [markdown]
# <img src="../images/bikes_banner.jpg" width="1000" />

# %% [markdown]
# # <span style="color:#37535e">Bicycle Share Usage</span>
#
# ##  <span style='color:#3b748a'>Plotting Indego Philly rental, weather, and daylight data</span>
#
# <span style='color:#4095b5'>This notebook explores the bike rental, weather, and daylight data for Indego Philly from July 2017 through June 2018 through various plots.</span>
#
# <span style='color:#4095b5'><b>NOTE</b>: While distance plots are created, these are not useful as distance is <b>calculated</b> from start and end hubs.</span>

# %% [markdown]
# ## <span style='color:#3b748a'>Table of contents</span>
# <ul>
#     <li><span style='color:#4095b5'><a href="#import"><span style='color:#4095b5'>I. Import all data.</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#process"><span style='color:#4095b5'>II. Process all data.</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#plot_trip"><span style='color:#4095b5'>III. Plot the trip data (trip counts, distances, durations).</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#plot_other"><span style='color:#4095b5'>IV. Plot bike data.</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#plot_other"><span style='color:#4095b5'>V. Plot other trip data (hubs, etc).</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#plot_weather"><span style='color:#4095b5'>VI. Plot the weather and daylight data.</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#corr"><span style='color:#4095b5'>VII. Plot correlations.</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#future"><span style='color:#4095b5'>VIII. Further work.</span></a></span></li>
#     <li><span style='color:#4095b5'><a href="#store"><span style='color:#4095b5'>IX. For future reference.</span></a></span></li>
# </ul>
#
# ## <span style='color:#3b748a'>External data required</span>
# <ul>
#     <li><span style='color:#4095b5'><a href="../data/phl/trips_all.csv"><span style='color:#4095b5'>../data/phl/trips_all.csv</span></a> (NOT available in GitHub)</span></li>
#     <li><span style='color:#4095b5'><a href='../data/phl/weather.csv'><span style='color:#4095b5'>../data/phl/weather.csv</span></a> (available in GitHub)</span></li>
#     <li><span style='color:#4095b5'><a href='../data/phl/daylight.csv'><span style='color:#4095b5'>../data/phl/daylight.csv</span></a> (available in GitHub)</span></li>
# </ul>
#
# ## <span style='color:#3b748a'>Links</span>
# * <span style='color:#4095b5'><a href="https://www.rideindego.com/about/data/">Indego (Philly) Data</a></span>
# * <a href="clean_phl.ipynb"><span style='color:#4095b5'>Cleaning Philadelphia trip data</span></a>
# * <a href="weather.ipynb"><span style='color:#4095b5'>Weather data</span></a>
# * <a href="daylight.ipynb"><span style='color:#4095b5'>Daylight data</span></a>
# <hr>

# %%
# Let's get the administrative stuff done first
# import all the libraries and set up the plotting

import pandas as pd
import numpy as np
from datetime import datetime,timedelta
from geopy.distance import vincenty

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns
colors_palette = sns.color_palette("GnBu_d")
sns.set_palette(colors_palette)
# %matplotlib inline

# GnBu_d
colors = ['#37535e', '#3b748a', '#4095b5', '#52aec9', '#72bfc4', '#93d0bf', '#c5e5eaff']

# %% [markdown]
# <hr>
# <a name="import"> </a>
# ## <span style='color:#3b748a'>I. Import all data.</span>

# %%
# NOTE: The trips_all.csv for bos, chi, phil, sf are TOO big to push to the GitHub repository
# NOTE: I don't have cleaned trip data for DC and NYC yet
# 'atl', 'bos', 'chi', 'la', 'phl', 'sf', 'dc', 'nyc'

city_code = 'phl'
city_name = "Philadelphia"

# %%
# Read and clean data for one city

# Bike trips for city
df_trips = pd.read_csv('../data/' + city_code + '/trips_all.csv')

# Weather for city
df_weather = pd.read_csv('../data/' + city_code + '/weather.csv')
df_weather.drop(['dew_avg', 'dew_max', 'dew_min', 'hum_max', 'hum_min', 'sea_avg', 'sea_max', 'sea_min',
         'temp_max', 'temp_min', 'vis_avg', 'vis_max', 'vis_min', 'wind_max', 'wind_unk'], 
        axis=1, inplace=True)

# A little cleaning
df_weather['prec'].replace(to_replace='T',value = '0.01', inplace=True)
df_weather['prec'] = df_weather['prec'].astype(float)

# For merging
df_weather.rename(columns={'date': 'Start Date'}, inplace=True)

# Daylight for city
df_daylight = pd.read_csv('../data/' + city_code + '/daylight.csv')

# For merging
df_daylight.rename(columns={'Date': 'Start Date'}, inplace=True)

# %% [markdown]
# <hr>
# <a name="process"> </a>
# ## <span style='color:#3b748a'>II. Process all data.</span>

# %%
# Type cast must happen after reading from csv    
df_trips['Start Date'] = pd.to_datetime(df_trips['Start Date'])
df_trips['End Date'] = pd.to_datetime(df_trips['End Date'])
df_trips['Start Time'] = pd.to_datetime(df_trips['Start Time'])
df_trips['End Time'] = pd.to_datetime(df_trips['End Time'])
df_trips['Duration'] = pd.to_timedelta(df_trips['Duration'], unit='m')
df_trips['Duration'] = (df_trips['Duration'].dt.total_seconds()/60) # minutes

# Type cast must happen after reading from csv
df_weather['Start Date'] = pd.to_datetime(df_weather['Start Date'])

# Fix daylight date and duration
df_daylight['Start Date'] = pd.to_datetime(df_daylight['Start Date'])
df_daylight['Daylight'] = pd.to_timedelta(df_daylight['Daylight'], unit='m')
df_daylight['Daylight'] = (df_daylight['Daylight'].dt.total_seconds()/60) # minutes

# %% [markdown]
#  ### <span style='color:#4095b5'>Create a "daily summary" DataFrame</span>

# %%
# Group the trips data frame by day and item and extract a number of stats from each day
# Used https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

df_daily = df_trips.groupby(['Start Date'], as_index=False).agg({
    "Duration": ['sum', 'count'],
    "Distance [Miles]" : ['sum']
})

df_daily.columns = ["_".join(x) for x in df_daily.columns.ravel()]
df_daily.rename(columns={
    'Start Date_' : 'Start Date',
    'Duration_count': 'Trips', 
    'Duration_sum' : 'Total Duration', 
    'Distance [Miles]_sum' : 'Total Distance'
}, inplace=True)

df_daily['Avg Duration'] = df_daily['Total Duration']/df_daily['Trips']
df_daily['Avg Distance'] = df_daily['Total Distance']/df_daily['Trips']

# %% [markdown]
#  #### <span style='color:#4095b5'>Merge daily, daylight, and weather</span>

# %%
# Merge daily, daylight, and weather on date
df = pd.merge(df_daily, df_weather, on = ['Start Date'], how = 'left')
df = pd.merge(df, df_daylight, on = ['Start Date'], how = 'left')

# %% [markdown]
#  #### <span style='color:#4095b5'>Add all parts of a date to the merged dataframe</span>

# %%
df['Date'] = df['Start Date'].astype(int)
df['Day'] = df['Start Date'].dt.strftime('%w').astype(int)
df['DayOfYear'] = df['Start Date'].dt.strftime('%-j').astype(int)
df['Week'] = df['Start Date'].dt.strftime('%W').astype(int)
df['Month'] = df['Start Date'].dt.strftime('%-m').astype(int)
df['Year'] = df['Start Date'].dt.strftime('%Y').astype(int)

# %% [markdown]
#  #### <span style='color:#4095b5'>Export the dataframe.</span>

# %%
df.to_csv('../data/' + city_code + '/daily.csv', index=False)

# %% [markdown]
#  ### <span style='color:#4095b5'>Create dataframes grouped by different time periods</span>

# %%
def groupby_period(period, df):
    df_period = df.groupby([period], as_index=False).agg({
        "Total Duration" : ['sum'],
        "Total Distance" : ['sum'],
        "Trips" : ['sum'],
        "Avg Duration" : ['mean'],
        "Avg Distance" : ['mean'],
        "hum_avg" : ['mean'],
        "prec" : ['mean'],
        "temp_avg" : ['mean'],
        "wind_avg" : ['mean']
    })

    df_period.columns = ["_".join(x) for x in df_period.columns.ravel()]
    df_period.rename(columns={
        period+'_' : period,
        'Total Duration_sum': 'Total Duration', 
        'Total Distance_sum': 'Total Distance', 
        'Trips_sum'         : 'Trips',
        'Avg Duration_mean' : 'Avg Duration',
        'Avg Distance_mean' : 'Avg Distance',
        'hum_avg_mean'      : 'Avg Humidity',
        'prec_mean'         : 'Avg Prec',
        'temp_avg_mean'     : 'Avg Temp',
        'wind_avg_mean'     : 'Avg Wind'
    }, inplace=True)
    
    return df_period

# %% [markdown]
#  #### <span style='color:#4095b5'>Create dataframes grouped by month, week, and day of week</span>

# %%
df_month = groupby_period('Month', df)
df_week = groupby_period('Week', df)
df_day = groupby_period('Day', df)

# %% [markdown]
# <hr>
# <a name="plot"> </a>
# ## <span style='color:#3b748a'>III. Plot trip data.</span>
#
# ### <span style='color:#4095b5'>Trips per time period data.</span>

# %%
# Setup
color_line = colors[1]
color_reg = colors[2]
color_dist = colors[2]
color_box = colors[3]

days_of_week = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday' ]

# %% [markdown]
#  #### <span style='color:#4095b5'>Statistics on day of week</span>

# %%
# For each day (365 days from sep 2017 - aug 2018)
df['Trips'].describe()
# Out:
# count     365.000000
# mean     2026.726027
# std       943.914361
# min       113.000000
# 25%      1275.000000
# 50%      2033.000000
# 75%      2846.000000
# max      3620.000000
# Name: Trips, dtype: float64

# %%
# This is really interesting to show that weather affects ridership!
df_temp = pd.DataFrame(df.sort_values(by="Trips", ascending=True).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 187 2018-01-04          3687.0    113      104.259908     32.628319
# 263 2018-03-21          2451.0    118      116.815167     20.771186
# 249 2018-03-07          2007.0    148      135.007980     13.560811
# 189 2018-01-06          3657.0    150      127.267173     24.380000
# 177 2017-12-25          4144.0    154      147.652960     26.909091
# 190 2018-01-07          6833.0    188      166.075793     36.345745
# 182 2017-12-30          4782.0    199      191.218956     24.030151
#
#      Avg Distance         events  hum_avg  prec  temp_avg  wind_avg  Month  \
# 187      0.922654       Fog,Snow       64  0.25        23        21      1
# 263      0.989959  Fog,Rain,Snow       78  1.06        34        16      3
# 249      0.912216  Fog,Rain,Snow       91  1.28        34        13      3
# 189      0.848448           None       45  0.00        12        17      1
# 177      0.958785      Rain,Snow       62  0.02        35        19     12
# 190      0.883382           None       47  0.00        12         9      1
# 182      0.960899           Snow       68  0.04        23         7     12
#
#      Week  Day
# 187     1    4
# 263    12    3
# 249    10    3
# 189     1    6
# 177    52    1
# 190     1    0
# 182    52    6

# %%
# This is really interesting to show that day of the week (and holidays) affect ridership
df_temp = pd.DataFrame(df.sort_values(by="Trips", ascending=False).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#    Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 25 2017-07-26         72097.0   3620     3838.823976     19.916298
# 60 2017-08-30         63343.0   3599     3878.125542     17.600167
# 39 2017-08-09         75479.0   3582     3810.414911     21.071748
# 68 2017-09-07         65660.0   3556     3894.372565     18.464567
# 61 2017-08-31         64039.0   3544     3777.127085     18.069695
# 10 2017-07-11         78489.0   3538     3755.283692     22.184568
# 54 2017-08-24         68346.0   3521     3828.234464     19.410963
#
#     Avg Distance events  hum_avg  prec  temp_avg  wind_avg  Month  Week  Day
# 25      1.060449   None       69  0.00        75         7      7    30    3
# 60      1.077556   None       64  0.00        69         9      8    35    3
# 39      1.063767   None       57  0.00        75         5      8    32    3
# 68      1.095155   Rain       66  0.03        66        11      9    36    4
# 61      1.065781   None       65  0.01        75         9      8    35    4
# 10      1.061414   None       66  0.00        84        10      7    28    2
# 54      1.087258   None       49  0.00        74         8      8    34    4

# %%
# Total trips per day
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['Trips'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Total Trips")
ax.set_title("Daily Total Trips in " + city_name);

# %%
# Distribution of # trips per day
ax = sns.distplot(df['Trips'], color=color_dist)
ax.set_title("Distribution of Total Trips per day in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### <span style='color:#4095b5'>Trips per day of week</span>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=df_day['Day'], y=df_day['Trips'], ax=ax);
ax.set_xlabel("Day of week")
ax.set_title("Total trips per day of week in " + city_name)
ax.set_xticklabels(days_of_week);

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='Day', y='Trips', data=df, color=color_box, ax=ax)
ax.set_title("Total trips per day of week in " + city_name)
ax.set_xticklabels(days_of_week)
ax.set_xlabel("Day of week");

# %% [markdown]
# ### <span style='color:#4095b5'>Trips per week</span>

# %%
fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_week['Week'], y=df_week['Trips'], ax=ax);
ax.set_xlabel("Week")
ax.set_title("Total trips per week in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Trips per month</span>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=df_month['Month'], y=df_month['Trips'], ax=ax);
ax.set_xlabel("Month")
ax.set_title("Total trips per month in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Total Durations per time period data.</span>

# %%
# This is really interesting to show that weather affects ridership!
df_temp = pd.DataFrame(df.sort_values(by="Total Duration", ascending=True).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 249 2018-03-07          2007.0    148      135.007980     13.560811
# 263 2018-03-21          2451.0    118      116.815167     20.771186
# 244 2018-03-02          3110.0    243      236.569703     12.798354
# 189 2018-01-06          3657.0    150      127.267173     24.380000
# 187 2018-01-04          3687.0    113      104.259908     32.628319
# 177 2017-12-25          4144.0    154      147.652960     26.909091
# 182 2017-12-30          4782.0    199      191.218956     24.030151
#
#      Avg Distance         events  hum_avg  prec  temp_avg  wind_avg  Month  \
# 249      0.912216  Fog,Rain,Snow       91  1.28        34        13      3
# 263      0.989959  Fog,Rain,Snow       78  1.06        34        16      3
# 244      0.973538  Fog,Rain,Snow       85  0.86        39        27      3
# 189      0.848448           None       45  0.00        12        17      1
# 187      0.922654       Fog,Snow       64  0.25        23        21      1
# 177      0.958785      Rain,Snow       62  0.02        35        19     12
# 182      0.960899           Snow       68  0.04        23         7     12
#
#      Week  Day
# 249    10    3
# 263    12    3
# 244     9    5
# 189     1    6
# 187     1    4
# 177    52    1
# 182    52    6

# %%
# This is really interesting to show that day of the week (and holidays) affect ridership
df_temp = pd.DataFrame(df.sort_values(by="Total Duration", ascending=False).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 287 2018-04-14         99494.0   2884     2989.286587     34.498613
# 119 2017-10-28         96679.0   3139     3330.468362     30.799299
# 3   2017-07-04         93990.0   3019     3082.488317     31.132825
# 98  2017-10-07         89501.0   2915     2883.292206     30.703602
# 70  2017-09-09         87904.0   2846     2978.207283     30.886859
# 65  2017-09-04         87129.0   2664     2691.004027     32.706081
# 1   2017-07-02         86871.0   2565     2662.439480     33.867836
#
#      Avg Distance             events  hum_avg  prec  temp_avg  wind_avg  \
# 287      1.036507               None       62  0.00        66        13
# 119      1.060997               None       64  0.00        60         8
# 3        1.021030  Rain,Thunderstorm       67  0.33        81         5
# 98       0.989123               None       72  0.00        75         9
# 70       1.046454               None       58  0.00        63        10
# 65       1.010137               None       61  0.00        72        10
# 1        1.037988               None       67  0.00        82         8
#
#      Month  Week  Day
# 287      4    15    6
# 119     10    43    6
# 3        7    27    2
# 98      10    40    6
# 70       9    36    6
# 65       9    36    1
# 1        7    26    0

# %%
ax = sns.distplot(df_trips['Duration'], color=color_dist)
ax.set_title("Distribution of All Trip Durations in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['Total Duration'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Total Durations in minutes")
ax.set_title("Total Durations per day in " + city_name);

# %%
# Distribution of durations per day
ax = sns.distplot(df['Total Duration'], color=color_dist)
ax.set_title("Distribution of Total Trip Durations per day in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### <span style='color:#4095b5'>Total durations per day of week</span>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=df_day['Day'], y=df_day['Total Duration'], ax=ax);
ax.set_xlabel("Day of week")
ax.set_title("Total trip durations per day of week in " + city_name)
ax.set_xticklabels(days_of_week);

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='Day', y='Total Duration', data=df, color=color_box, ax=ax)
ax.set_title("Total trip durations per day of week in " + city_name)
ax.set_xticklabels(days_of_week)
ax.set_xlabel("Day of week");

# %% [markdown]
# ### <span style='color:#4095b5'>Total durations per week</span>

# %%
fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_week['Week'], y=df_week['Total Duration'], ax=ax);
ax.set_xlabel("Week")
ax.set_title("Total durations of trips per week in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Total durations per month</span>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=df_month['Month'], y=df_month['Total Duration'], ax=ax);
ax.set_xlabel("Month")
ax.set_title("Total durations of trips per month in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Average Durations per time period data.</span>

# %%
# This is really interesting to show that weather affects ridership!
df_temp = pd.DataFrame(df.sort_values(by="Avg Duration", ascending=True).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 262 2018-03-20          8370.0    741      770.455359     11.295547
# 276 2018-04-03         13539.0   1107     1141.082909     12.230352
# 220 2018-02-06         17082.0   1382     1394.950874     12.360347
# 236 2018-02-22         14139.0   1105     1128.481741     12.795475
# 244 2018-03-02          3110.0    243      236.569703     12.798354
# 228 2018-02-14         19626.0   1512     1587.642489     12.980159
# 227 2018-02-13         17825.0   1360     1422.811079     13.106618
#
#      Avg Distance         events  hum_avg  prec  temp_avg  wind_avg  Month  \
# 262      1.039751      Rain,Snow       64  0.40        32        14      3
# 276      1.030789           Rain       90  0.08        42         6      4
# 220      1.009371           Snow       60  0.01        32         5      2
# 236      1.021250           Rain       67  0.06        48        13      2
# 244      0.973538  Fog,Rain,Snow       85  0.86        39        27      3
# 228      1.050028           Rain       64  0.05        44         9      2
# 227      1.046185           None       49  0.00        35         8      2
#
#      Week  Day
# 262    12    2
# 276    14    2
# 220     6    2
# 236     8    4
# 244     9    5
# 228     7    3
# 227     7    2

# %%
# This is really interesting to show that day of the week (and holidays) affect ridership
df_temp = pd.DataFrame(df.sort_values(by="Avg Duration", ascending=False).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 184 2018-01-01          8126.0    201      178.270577     40.427861
# 106 2017-10-15         80795.0   2024     2068.084139     39.918478
# 222 2018-02-08         69278.0   1809     2085.219972     38.296296
# 190 2018-01-07          6833.0    188      166.075793     36.345745
# 188 2018-01-05          8040.0    232      215.758350     34.655172
# 64  2017-09-03         79316.0   2290     2405.714039     34.635808
# 287 2018-04-14         99494.0   2884     2989.286587     34.498613
#
#      Avg Distance events  hum_avg  prec  temp_avg  wind_avg  Month  Week  Day
# 184      0.886918   None       47  0.00        13        11      1     1    1
# 106      1.021781   None       83  0.01        69         9     10    41    0
# 222      1.152692   None       54  0.00        32        12      2     6    4
# 190      0.883382   None       47  0.00        12         9      1     1    0
# 188      0.929993   None       44  0.00        14        22      1     1    5
# 64       1.050530   Rain       79  0.01        68         9      9    35    0
# 287      1.036507   None       62  0.00        66        13      4    15    6

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['Avg Duration'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Avg Durations in minutes")
ax.set_title("Average Durations per day in " + city_name);

# %%
# Distribution of durations per day
ax = sns.distplot(df['Avg Duration'], color=color_dist)
ax.set_title("Distribution of Average Trip Durations per day in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### <span style='color:#4095b5'>Average durations per day of week</span>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=df_day['Day'], y=df_day['Avg Duration'], ax=ax);
ax.set_xlabel("Day of week")
ax.set_title("Average trip durations per day of week in " + city_name)
ax.set_xticklabels(days_of_week);

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='Day', y='Avg Duration', data=df, color=color_box, ax=ax)
ax.set_title("Average trip durations per day of week in " + city_name)
ax.set_xticklabels(days_of_week)
ax.set_xlabel("Day of week");

# %%
# What are the outliers for Philly?
# 15 oct 2017 - ??
# df[df['Day'] == 0].sort_values(by='Avg Duration', ascending=False)
# 1 jan 2018 - New Years, 4 sep 2017 (Labor Day)
# df[df['Day'] == 1].sort_values(by='Avg Duration', ascending=False)
# 8 feb 2018 - 
#df[df['Day'] == 4].sort_values(by='Avg Duration', ascending=False)

# %% [markdown]
# ### <span style='color:#4095b5'>Average durations per week</span>

# %%
fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_week['Week'], y=df_week['Avg Duration'], ax=ax);
ax.set_xlabel("Week")
ax.set_title("Average durations of trips per week in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Average durations per month</span>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=df_month['Month'], y=df_month['Avg Duration'], ax=ax);
ax.set_xlabel("Month")
ax.set_title("Average durations of trips per month in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Total Distance per time period data.</span>

# %%
# This is really interesting to show that weather affects ridership!
df_temp = pd.DataFrame(df.sort_values(by="Total Distance", ascending=True).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 187 2018-01-04          3687.0    113      104.259908     32.628319
# 263 2018-03-21          2451.0    118      116.815167     20.771186
# 189 2018-01-06          3657.0    150      127.267173     24.380000
# 249 2018-03-07          2007.0    148      135.007980     13.560811
# 177 2017-12-25          4144.0    154      147.652960     26.909091
# 190 2018-01-07          6833.0    188      166.075793     36.345745
# 184 2018-01-01          8126.0    201      178.270577     40.427861
#
#      Avg Distance         events  hum_avg  prec  temp_avg  wind_avg  Month  \
# 187      0.922654       Fog,Snow       64  0.25        23        21      1
# 263      0.989959  Fog,Rain,Snow       78  1.06        34        16      3
# 189      0.848448           None       45  0.00        12        17      1
# 249      0.912216  Fog,Rain,Snow       91  1.28        34        13      3
# 177      0.958785      Rain,Snow       62  0.02        35        19     12
# 190      0.883382           None       47  0.00        12         9      1
# 184      0.886918           None       47  0.00        13        11      1
#
#      Week  Day
# 187     1    4
# 263    12    3
# 189     1    6
# 249    10    3
# 177    52    1
# 190     1    0
# 184     1    1

# %%
# This is really interesting to show that day of the week (and holidays) affect ridership
df_temp = pd.DataFrame(df.sort_values(by="Total Distance", ascending=False).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#    Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 68 2017-09-07         65660.0   3556     3894.372565     18.464567
# 60 2017-08-30         63343.0   3599     3878.125542     17.600167
# 73 2017-09-12         68893.0   3498     3842.758148     19.694969
# 25 2017-07-26         72097.0   3620     3838.823976     19.916298
# 54 2017-08-24         68346.0   3521     3828.234464     19.410963
# 95 2017-10-04         59165.0   3518     3825.684966     16.817794
# 39 2017-08-09         75479.0   3582     3810.414911     21.071748
#
#     Avg Distance events  hum_avg  prec  temp_avg  wind_avg  Month  Week  Day
# 68      1.095155   Rain       66  0.03        66        11      9    36    4
# 60      1.077556   None       64  0.00        69         9      8    35    3
# 73      1.098559   None       57  0.00        70         4      9    37    2
# 25      1.060449   None       69  0.00        75         7      7    30    3
# 54      1.087258   None       49  0.00        74         8      8    34    4
# 95      1.087460   None       68  0.00        65         8     10    40    3
# 39      1.063767   None       57  0.00        75         5      8    32    3

# %%
ax = sns.distplot(df_trips['Distance [Miles]'], color=color_dist)
ax.set_title("Distribution of All Trip Distances in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['Total Distance'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Total Distances in miles")
ax.set_title("Total Distance per day in " + city_name);

# %%
# Distribution of distances per day
ax = sns.distplot(df['Total Distance'], color=color_dist)
ax.set_title("Distribution of Total Trip Distances per day in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### <span style='color:#4095b5'>Total distances per day of week</span>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=df_day['Day'], y=df_day['Total Distance'], ax=ax);
ax.set_xlabel("Day of week")
ax.set_title("Total trip distances per day of week in " + city_name)
ax.set_xticklabels(days_of_week);

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='Day', y='Total Distance', data=df, color=color_box, ax=ax)
ax.set_title("Total trip distances per day of week in " + city_name)
ax.set_xticklabels(days_of_week)
ax.set_xlabel("Day of week");

# %% [markdown]
# ### <span style='color:#4095b5'>Total distances per week</span>

# %%
fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_week['Week'], y=df_week['Total Distance'], ax=ax);
ax.set_xlabel("Week")
ax.set_title("Total distances of trips per week in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Total distances per month</span>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=df_month['Month'], y=df_month['Total Distance'], ax=ax);
ax.set_xlabel("Month")
ax.set_title("Total distances of trips per month in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Average Distances per time period data.</span>

# %%
# This is really interesting to show that weather affects ridership!
df_temp = pd.DataFrame(df.sort_values(by="Avg Distance", ascending=True).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 189 2018-01-06          3657.0    150      127.267173     24.380000
# 190 2018-01-07          6833.0    188      166.075793     36.345745
# 184 2018-01-01          8126.0    201      178.270577     40.427861
# 249 2018-03-07          2007.0    148      135.007980     13.560811
# 187 2018-01-04          3687.0    113      104.259908     32.628319
# 188 2018-01-05          8040.0    232      215.758350     34.655172
# 183 2017-12-31          4833.0    234      217.822075     20.653846
#
#      Avg Distance         events  hum_avg  prec  temp_avg  wind_avg  Month  \
# 189      0.848448           None       45  0.00        12        17      1
# 190      0.883382           None       47  0.00        12         9      1
# 184      0.886918           None       47  0.00        13        11      1
# 249      0.912216  Fog,Rain,Snow       91  1.28        34        13      3
# 187      0.922654       Fog,Snow       64  0.25        23        21      1
# 188      0.929993           None       44  0.00        14        22      1
# 183      0.930864           None       50  0.00        15        12     12
#
#      Week  Day
# 189     1    6
# 190     1    0
# 184     1    1
# 249    10    3
# 187     1    4
# 188     1    5
# 183    52    0

# %%
# This is really interesting to show that day of the week (and holidays) affect ridership
df_temp = pd.DataFrame(df.sort_values(by="Avg Distance", ascending=False).head(7)[['Start Date', 'Total Duration', 'Trips', 'Total Distance',
       'Avg Duration', 'Avg Distance', 'events', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Month', 'Week', 'Day']])
df_temp
# Out:
#     Start Date  Total Duration  Trips  Total Distance  Avg Duration  \
# 222 2018-02-08         69278.0   1809     2085.219972     38.296296
# 242 2018-02-28         30761.0   1880     2066.645162     16.362234
# 299 2018-04-26         33608.0   2182     2397.816710     15.402383
# 73  2017-09-12         68893.0   3498     3842.758148     19.694969
# 75  2017-09-14         61871.0   3417     3749.096306     18.106819
# 68  2017-09-07         65660.0   3556     3894.372565     18.464567
# 311 2018-05-08         55468.0   2885     3146.010932     19.226343
#
#      Avg Distance events  hum_avg  prec  temp_avg  wind_avg  Month  Week  Day
# 222      1.152692   None       54  0.00        32        12      2     6    4
# 242      1.099279   None       50  0.00        50        10      2     9    3
# 299      1.098908   None       61  0.00        59        11      4    17    4
# 73       1.098559   None       57  0.00        70         4      9    37    2
# 75       1.097189   None       74  0.00        77         8      9    37    4
# 68       1.095155   Rain       66  0.03        66        11      9    36    4
# 311      1.090472   None       59  0.00        64         6      5    19    2

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['Avg Distance'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Avg Distance in miles")
ax.set_title("Average Distances per day in " + city_name);

# %%
# Distribution of distances per day
ax = sns.distplot(df['Avg Distance'], color=color_dist)
ax.set_title("Distribution of Average Trip Distances per day in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### <span style='color:#4095b5'>Average distances per day of week</span>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=df_day['Day'], y=df_day['Avg Distance'], ax=ax);
ax.set_xlabel("Day of week")
ax.set_title("Average trip distances per day of week in " + city_name)
ax.set_xticklabels(days_of_week);

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='Day', y='Avg Distance', data=df, color=color_box, ax=ax)
ax.set_title("Average trip distances per day of week in " + city_name)
ax.set_xticklabels(days_of_week)
ax.set_xlabel("Day of week");

# %%
# What are the outliers?
# 26 dec 2017
# df[df['Day'] == '2'].sort_values(by='Avg Distance', ascending=False)
# 8 jun 2018 (Atlanta Moon Ride)
# df[df['Day'] == '5'].sort_values(by='Avg Distance', ascending=False)

# 8 dec 2017 - Snow, 12 jan 2018, - cold and wet, 15 dec 2017 - cold 
# df[df['Day'] == '5'].sort_values(by='Avg Distance', ascending=True)
# 23 dec 2017 : Rainy saturday, close to Christmas, 10 feb 2018 - rainy, 9 dec 2017 - snow
# df[df['Day'] == '6'].sort_values(by='Avg Distance', ascending=True)

# %% [markdown]
# ### <span style='color:#4095b5'>Average distances per week</span>

# %%
fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_week['Week'], y=df_week['Avg Distance'], ax=ax);
ax.set_xlabel("Week")
ax.set_title("Average distances of trips per week in " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Average distances per month</span>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=df_month['Month'], y=df_month['Avg Distance'], ax=ax);
ax.set_xlabel("Month")
ax.set_title("Average distances of trips per month in " + city_name);

# %% [markdown]
# <hr>
# <a name="plot_bike"> </a>
# ## <span style='color:#3b748a'>IV. Plot bike data.</span>

# %%
df_bikes = df_trips.groupby(['Bike Name'], as_index=False).agg({
        "Duration" : ['sum', 'mean', 'count'],
        "Distance [Miles]" : ['sum', 'mean']
    })

df_bikes.columns = ["_".join(x) for x in df_bikes.columns.ravel()]
df_bikes.rename(columns={
    'Bike Name_' : 'Bike Name',
    'Duration_count': 'Trips', 
    'Duration_sum' : 'Total Duration', 
    'Duration_mean' : 'Avg Duration', 
    'Distance [Miles]_sum' : 'Total Distance',
    'Distance [Miles]_mean' : 'Avg Distance'
}, inplace=True)

# %% [markdown]
#  #### <span style='color:#4095b5'>Export the dataframe.</span>

# %%
df_bikes.to_csv('../data/' + city_code + '/bikes.csv', index=False)

# %% [markdown]
#  #### <span style='color:#4095b5'>Explore the data.</span>

# %%
df_bikes.describe()
# Out:
#           Bike Name  Total Duration  Avg Duration        Trips  \
# count   1236.000000     1236.000000   1236.000000  1236.000000
# mean    5776.283172    11980.813107     22.161181   598.507282
# std     3553.721916     3248.701620     47.235646   152.978983
# min       14.000000       65.000000      9.285714     1.000000
# 25%     3347.750000     9966.250000     18.270262   512.750000
# 50%     3700.500000    11828.500000     19.689981   592.000000
# 75%     7794.750000    14160.250000     21.451809   706.000000
# max    11965.000000    32926.000000   1305.000000  1321.000000
#
#        Total Distance  Avg Distance
# count     1236.000000   1236.000000
# mean       624.315524      1.045413
# std        159.661944      0.051317
# min          0.903592      0.860001
# 25%        533.893289      1.022690
# 50%        618.043977      1.043351
# 75%        733.878963      1.064445
# max       1238.917704      1.982839

# %%
ax = sns.distplot(df_bikes['Trips'], color=color_dist)
ax.set_title("Distribution of trips per bike in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
ax = sns.distplot(df_bikes['Total Distance'], color=color_dist)
ax.set_title("Distribution of total distance per bike in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
ax = sns.distplot(df_bikes['Total Duration'], color=color_dist)
ax.set_title("Distribution of total duration per bike in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# <hr>
# <a name="plot_trip_other"> </a>
# ## <span style='color:#3b748a'>V. Plot other trip data.</span>

# %% [markdown]
# ### <span style='color:#4095b5'>Hub data</span>

# %%
# Add station names
df_hubs = pd.read_csv("../data/phl/indego-stations-2018-8-3.csv")

# %%
df_hubs.drop(['Go live date', 'Status'], axis=1, inplace=True)

# %%
df_trips = df_trips.merge(df_hubs, left_on='Start Hub', right_on='Station ID', how='left')
df_trips.rename(columns={'Station Name' : 'Start Hub Name'
                      }, inplace=True)

df_trips = df_trips.merge(df_hubs, left_on='End Hub', right_on='Station ID', how='left')
df_trips.rename(columns={'Station Name' : 'End Hub Name'
                      }, inplace=True)

# %%
df_trips
# Out:
#         Start Hub  Start Latitude  Start Longitude Start Date  \
# 0            3160       39.956619       -75.198624 2017-07-01
# 1            3046       39.950119       -75.144722 2017-07-01
# 2            3006       39.952202       -75.203110 2017-07-01
# 3            3006       39.952202       -75.203110 2017-07-01
# 4            3046       39.950119       -75.144722 2017-07-01
# 5            3010       39.947109       -75.166183 2017-07-01
# 6            3070       39.960621       -75.139832 2017-07-01
# 7            3052       39.947319       -75.156952 2017-07-01
# 8            3026       39.941380       -75.145638 2017-07-01
# 9            3037       39.954239       -75.161377 2017-07-01
# 10           3041       39.968491       -75.135460 2017-07-01
# 11           3052       39.947319       -75.156952 2017-07-01
# 12           3052       39.947319       -75.156952 2017-07-01
# 13           3052       39.947319       -75.156952 2017-07-01
# 14           3063       39.946331       -75.169800 2017-07-01
# 15           3063       39.946331       -75.169800 2017-07-01
# 16           3125       39.943909       -75.167351 2017-07-01
# 17           3020       39.949219       -75.190361 2017-07-01
# 18           3099       39.934010       -75.150940 2017-07-01
# 19           3026       39.941380       -75.145638 2017-07-01
# 20           3061       39.954250       -75.177612 2017-07-01
# 21           3072       39.934448       -75.145409 2017-07-01
# 22           3032       39.945271       -75.179710 2017-07-01
# 23           3124       39.952950       -75.139793 2017-07-01
# 24           3157       39.925449       -75.159538 2017-07-01
# 25           3157       39.925449       -75.159538 2017-07-01
# 26           3008       39.980782       -75.150551 2017-07-01
# 27           3057       39.964581       -75.180031 2017-07-01
# 28           3028       39.940609       -75.149582 2017-07-01
# 29           3057       39.964581       -75.180031 2017-07-01
# ...           ...             ...              ...        ...
# 739725       3010       39.947109       -75.166183 2018-06-30
# 739726       3009       39.955761       -75.189819 2018-06-30
# 739727       3028       39.940609       -75.149582 2018-06-30
# 739728       3028       39.940609       -75.149582 2018-06-30
# 739729       3056       39.976688       -75.158127 2018-06-30
# 739730       3097       39.978882       -75.133392 2018-06-30
# 739731       3010       39.947109       -75.166183 2018-06-30
# 739732       3010       39.947109       -75.166183 2018-06-30
# 739733       3009       39.955761       -75.189819 2018-06-30
# 739734       3026       39.941380       -75.145638 2018-06-30
# 739735       3068       39.935490       -75.167107 2018-06-30
# 739736       3068       39.935490       -75.167107 2018-06-30
# 739737       3026       39.941380       -75.145638 2018-06-30
# 739738       3068       39.935490       -75.167107 2018-06-30
# 739739       3005       39.947330       -75.144028 2018-06-30
# 739740       3015       39.947350       -75.148857 2018-06-30
# 739741       3064       39.938400       -75.173271 2018-06-30
# 739742       3005       39.947330       -75.144028 2018-06-30
# 739743       3068       39.935490       -75.167107 2018-06-30
# 739744       3052       39.947319       -75.156952 2018-06-30
# 739745       3166       39.972351       -75.134453 2018-06-30
# 739746       3054       39.962502       -75.174202 2018-06-30
# 739747       3015       39.947350       -75.148857 2018-06-30
# 739748       3075       39.967178       -75.161247 2018-06-30
# 739749       3075       39.967178       -75.161247 2018-06-30
# 739750       3043       39.930820       -75.174744 2018-06-30
# 739751       3021       39.953899       -75.169022 2018-06-30
# 739752       3043       39.930820       -75.174744 2018-06-30
# 739753       3007       39.945171       -75.159927 2018-06-30
# 739754       3100       39.927769       -75.151031 2018-06-30
#
#                 Start Time  End Hub  End Latitude  End Longitude   End Date  \
# 0      2017-07-01 00:04:00     3163     39.949741     -75.180969 2017-07-01
# 1      2017-07-01 00:06:00     3101     39.942951     -75.159554 2017-07-01
# 2      2017-07-01 00:06:00     3101     39.942951     -75.159554 2017-07-01
# 3      2017-07-01 00:06:00     3101     39.942951     -75.159554 2017-07-01
# 4      2017-07-01 00:07:00     3101     39.942951     -75.159554 2017-07-01
# 5      2017-07-01 00:08:00     3099     39.934010     -75.150940 2017-07-01
# 6      2017-07-01 00:10:00     3124     39.952950     -75.139793 2017-07-01
# 7      2017-07-01 00:16:00     3046     39.950119     -75.144722 2017-07-01
# 8      2017-07-01 00:16:00     3018     39.952728     -75.159790 2017-07-01
# 9      2017-07-01 00:17:00     3053     39.932308     -75.181541 2017-07-01
# 10     2017-07-01 00:17:00     3059     39.962650     -75.161743 2017-07-01
# 11     2017-07-01 00:17:00     3046     39.950119     -75.144722 2017-07-01
# 12     2017-07-01 00:18:00     3005     39.947330     -75.144028 2017-07-01
# 13     2017-07-01 00:19:00     3005     39.947330     -75.144028 2017-07-01
# 14     2017-07-01 00:19:00     3023     39.950481     -75.172859 2017-07-01
# 15     2017-07-01 00:20:00     3023     39.950481     -75.172859 2017-07-01
# 16     2017-07-01 00:20:00     3032     39.945271     -75.179710 2017-07-01
# 17     2017-07-01 00:22:00     3032     39.945271     -75.179710 2017-07-01
# 18     2017-07-01 00:23:00     3028     39.940609     -75.149582 2017-07-01
# 19     2017-07-01 00:24:00     3051     39.967442     -75.175072 2017-07-01
# 20     2017-07-01 00:27:00     3057     39.964581     -75.180031 2017-07-01
# 21     2017-07-01 00:30:00     3007     39.945171     -75.159927 2017-07-01
# 22     2017-07-01 00:31:00     3032     39.945271     -75.179710 2017-07-01
# 23     2017-07-01 00:33:00     3056     39.976688     -75.158127 2017-07-01
# 24     2017-07-01 00:34:00     3170     39.944260     -75.181343 2017-07-01
# 25     2017-07-01 00:34:00     3170     39.944260     -75.181343 2017-07-01
# 26     2017-07-01 00:34:00     3051     39.967442     -75.175072 2017-07-01
# 27     2017-07-01 00:34:00     3057     39.964581     -75.180031 2017-07-01
# 28     2017-07-01 00:35:00     3117     39.978409     -75.223991 2017-07-01
# 29     2017-07-01 00:36:00     3057     39.964581     -75.180031 2017-07-01
# ...                    ...      ...           ...            ...        ...
# 739725 2018-06-30 23:20:00     3032     39.945271     -75.179710 2018-06-30
# 739726 2018-06-30 23:25:00     3104     39.966640     -75.192093 2018-06-30
# 739727 2018-06-30 23:28:00     3099     39.934010     -75.150940 2018-06-30
# 739728 2018-06-30 23:28:00     3099     39.934010     -75.150940 2018-06-30
# 739729 2018-06-30 23:29:00     3075     39.967178     -75.161247 2018-06-30
# 739730 2018-06-30 23:33:00     3099     39.934010     -75.150940 2018-07-01
# 739731 2018-06-30 23:34:00     3064     39.938400     -75.173271 2018-06-30
# 739732 2018-06-30 23:34:00     3064     39.938400     -75.173271 2018-06-30
# 739733 2018-06-30 23:35:00     3006     39.952202     -75.203110 2018-06-30
# 739734 2018-06-30 23:35:00     3026     39.941380     -75.145638 2018-07-01
# 739735 2018-06-30 23:35:00     3100     39.927769     -75.151031 2018-07-01
# 739736 2018-06-30 23:36:00     3100     39.927769     -75.151031 2018-07-01
# 739737 2018-06-30 23:37:00     3026     39.941380     -75.145638 2018-07-01
# 739738 2018-06-30 23:38:00     3100     39.927769     -75.151031 2018-07-01
# 739739 2018-06-30 23:41:00     3018     39.952728     -75.159790 2018-06-30
# 739740 2018-06-30 23:42:00     3063     39.946331     -75.169800 2018-06-30
# 739741 2018-06-30 23:42:00     3045     39.947922     -75.162369 2018-06-30
# 739742 2018-06-30 23:42:00     3018     39.952728     -75.159790 2018-06-30
# 739743 2018-06-30 23:42:00     3124     39.952950     -75.139793 2018-07-01
# 739744 2018-06-30 23:43:00     3073     39.961430     -75.152420 2018-06-30
# 739745 2018-06-30 23:46:00     3115     39.972630     -75.167572 2018-07-01
# 739746 2018-06-30 23:47:00     3053     39.932308     -75.181541 2018-07-01
# 739747 2018-06-30 23:48:00     3045     39.947922     -75.162369 2018-06-30
# 739748 2018-06-30 23:49:00     3102     39.967590     -75.179520 2018-07-01
# 739749 2018-06-30 23:49:00     3102     39.967590     -75.179520 2018-07-01
# 739750 2018-06-30 23:52:00     3032     39.945271     -75.179710 2018-07-01
# 739751 2018-06-30 23:52:00     3007     39.945171     -75.159927 2018-07-01
# 739752 2018-06-30 23:53:00     3032     39.945271     -75.179710 2018-07-01
# 739753 2018-06-30 23:54:00     3010     39.947109     -75.166183 2018-06-30
# 739754 2018-06-30 23:56:00     3046     39.950119     -75.144722 2018-07-01
#
#                   End Time  Bike Name  Distance [Miles]  Duration  \
# 0      2017-07-01 00:16:00      11883          1.050700      12.0
# 1      2017-07-01 00:37:00       5394          0.930008      31.0
# 2      2017-07-01 00:21:00       3331          2.399353      15.0
# 3      2017-07-01 00:21:00       3515          2.399353      15.0
# 4      2017-07-01 00:37:00      11913          0.930008      30.0
# 5      2017-07-01 00:22:00       2555          1.213284      14.0
# 6      2017-07-01 00:16:00      11019          0.529251       6.0
# 7      2017-07-01 00:31:00       2720          0.677548      15.0
# 8      2017-07-01 01:12:00      11900          1.085238      56.0
# 9      2017-07-01 00:38:00       5406          1.853664      21.0
# 10     2017-07-01 00:30:00       2703          1.452340      13.0
# 11     2017-07-01 00:31:00       3554          0.677548      14.0
# 12     2017-07-01 00:37:00       2531          0.686291      19.0
# 13     2017-07-01 00:36:00       3553          0.686291      17.0
# 14     2017-07-01 00:44:00       5302          0.329189      25.0
# 15     2017-07-01 00:44:00       2573          0.329189      24.0
# 16     2017-07-01 00:30:00      11893          0.663007      10.0
# 17     2017-07-01 00:27:00       5157          0.627763       5.0
# 18     2017-07-01 00:29:00       3542          0.460962       6.0
# 19     2017-07-01 00:46:00       2656          2.382361      22.0
# 20     2017-07-01 00:38:00       5215          0.724247      11.0
# 21     2017-07-01 00:42:00       3285          1.068547      12.0
# 22     2017-07-01 00:46:00       3396          0.000000      15.0
# 23     2017-07-01 00:51:00      11747          1.905158      18.0
# 24     2017-07-01 00:53:00       2568          1.739410      19.0
# 25     2017-07-01 00:53:00       3690          1.739410      19.0
# 26     2017-07-01 00:53:00       2644          1.594135      19.0
# 27     2017-07-01 01:55:00       3733          0.000000      81.0
# 28     2017-07-01 02:01:00       5191          4.733747      86.0
# 29     2017-07-01 01:55:00      11887          0.000000      79.0
# ...                    ...        ...               ...       ...
# 739725 2018-06-30 23:29:00       2680          0.729430       9.0
# 739726 2018-06-30 23:58:00      11712          0.760225      33.0
# 739727 2018-06-30 23:33:00       5254          0.460962       5.0
# 739728 2018-06-30 23:46:00      11835          0.460962      18.0
# 739729 2018-06-30 23:35:00       5200          0.676707       6.0
# 739730 2018-07-01 00:03:00       5177          3.233025      30.0
# 739731 2018-06-30 23:40:00       5233          0.709027       6.0
# 739732 2018-06-30 23:40:00       2580          0.709027       6.0
# 739733 2018-06-30 23:44:00       3340          0.747209       9.0
# 739734 2018-07-01 00:08:00       5148          0.000000      33.0
# 739735 2018-07-01 00:12:00       2647          1.006402      37.0
# 739736 2018-07-01 00:12:00       3501          1.006402      36.0
# 739737 2018-07-01 00:07:00       3464          0.000000      30.0
# 739738 2018-07-01 00:12:00       3466          1.006402      34.0
# 739739 2018-06-30 23:57:00       3710          0.916081      16.0
# 739740 2018-06-30 23:51:00      11811          1.114344       9.0
# 739741 2018-06-30 23:49:00       5128          0.875656       7.0
# 739742 2018-06-30 23:57:00       3399          0.916081      15.0
# 739743 2018-07-01 00:04:00       3433          1.885481      22.0
# 739744 2018-06-30 23:52:00       3434          1.002860       9.0
# 739745 2018-07-01 00:03:00       3402          1.758147      17.0
# 739746 2018-07-01 00:04:00      11907          2.119317      17.0
# 739747 2018-06-30 23:56:00       3562          0.718596       8.0
# 739748 2018-07-01 00:03:00       5364          0.970466      14.0
# 739749 2018-07-01 00:03:00       5200          0.970466      14.0
# 739750 2018-07-01 00:03:00       3527          1.031311      11.0
# 739751 2018-07-01 00:03:00       3284          0.771913      11.0
# 739752 2018-07-01 00:03:00       5296          1.031311      10.0
# 739753 2018-06-30 23:58:00      11776          0.358110       4.0
# 739754 2018-07-01 00:12:00       3497          1.577977      16.0
#
#         Station ID_x                      Start Hub Name  Station ID_y  \
# 0             3160.0                       38th & Market        3163.0
# 1             3046.0                        2nd & Market        3101.0
# 2             3006.0                       40th & Spruce        3101.0
# 3             3006.0                       40th & Spruce        3101.0
# 4             3046.0                        2nd & Market        3101.0
# 5             3010.0                       15th & Spruce        3099.0
# 6             3070.0          Spring Garden Station, MFL        3124.0
# 7             3052.0                        9th & Locust        3046.0
# 8             3026.0                         2nd & South        3018.0
# 9             3037.0      Pennsylvania Convention Center        3053.0
# 10            3041.0                 Girard Station, MFL        3059.0
# 11            3052.0                        9th & Locust        3046.0
# 12            3052.0                        9th & Locust        3005.0
# 13            3052.0                        9th & Locust        3005.0
# 14            3063.0                         17th & Pine        3023.0
# 15            3063.0                         17th & Pine        3023.0
# 16            3125.0                        15th & South        3032.0
# 17            3020.0             University City Station        3032.0
# 18            3099.0                    4th & Washington        3028.0
# 19            3026.0                         2nd & South        3051.0
# 20            3061.0                       23rd & Market        3057.0
# 21            3072.0                   Front & Carpenter        3007.0
# 22            3032.0                        23rd & South        3032.0
# 23            3124.0                    Race Street Pier        3056.0
# 24            3157.0         8th & Mifflin, Bok Building        3170.0
# 25            3157.0         8th & Mifflin, Bok Building        3170.0
# 26            3008.0           Temple University Station        3051.0
# 27            3057.0          Philadelphia Museum of Art        3057.0
# 28            3028.0                    4th & Bainbridge        3117.0
# 29            3057.0          Philadelphia Museum of Art        3057.0
# ...              ...                                 ...           ...
# 739725        3010.0                       15th & Spruce        3032.0
# 739726        3009.0                       33rd & Market        3104.0
# 739727        3028.0                    4th & Bainbridge        3099.0
# 739728        3028.0                    4th & Bainbridge        3099.0
# 739729        3056.0                      Broad & Oxford        3075.0
# 739730        3097.0                  Berks Station, MFL        3099.0
# 739731        3010.0                       15th & Spruce        3064.0
# 739732        3010.0                       15th & Spruce        3064.0
# 739733        3009.0                       33rd & Market        3006.0
# 739734        3026.0                         2nd & South        3026.0
# 739735        3068.0                     Broad & Federal        3100.0
# 739736        3068.0                     Broad & Federal        3100.0
# 739737        3026.0                         2nd & South        3026.0
# 739738        3068.0                     Broad & Federal        3100.0
# 739739        3005.0                   Welcome Park, NPS        3018.0
# 739740        3015.0                   4th & Walnut, NPS        3063.0
# 739741        3064.0  18th & Washington, Chew Playground        3045.0
# 739742        3005.0                   Welcome Park, NPS        3018.0
# 739743        3068.0                     Broad & Federal        3124.0
# 739744        3052.0                        9th & Locust        3073.0
# 739745        3166.0                Frankford & Belgrade        3115.0
# 739746        3054.0                        Rodin Museum        3053.0
# 739747        3015.0                   4th & Walnut, NPS        3045.0
# 739748        3075.0                   Fairmount & Ridge        3102.0
# 739749        3075.0                   Fairmount & Ridge        3102.0
# 739750        3043.0       18th & Fernon, Aquinas Center        3032.0
# 739751        3021.0                          18th & JFK        3007.0
# 739752        3043.0       18th & Fernon, Aquinas Center        3032.0
# 739753        3007.0              11th & Pine, Kahn Park        3010.0
# 739754        3100.0                Moyamensing & Tasker        3046.0
#
#                               End Hub Name
# 0                            25th & Locust
# 1                             11th & South
# 2                             11th & South
# 3                             11th & South
# 4                             11th & South
# 5                         4th & Washington
# 6                         Race Street Pier
# 7                             2nd & Market
# 8                           12th & Filbert
# 9                    Point Breeze & Tasker
# 10              Spring Garden Station, BSL
# 11                            2nd & Market
# 12                       Welcome Park, NPS
# 13                       Welcome Park, NPS
# 14                      Rittenhouse Square
# 15                      Rittenhouse Square
# 16                            23rd & South
# 17                            23rd & South
# 18                        4th & Bainbridge
# 19                        23rd & Fairmount
# 20              Philadelphia Museum of Art
# 21                  11th & Pine, Kahn Park
# 22                            23rd & South
# 23                          Broad & Oxford
# 24                 Grays Ferry & Pemberton
# 25                 Grays Ferry & Pemberton
# 26                        23rd & Fairmount
# 27              Philadelphia Museum of Art
# 28                    ParkWest Town Center
# 29              Philadelphia Museum of Art
# ...                                    ...
# 739725                        23rd & South
# 739726                       34th & Mantua
# 739727                    4th & Washington
# 739728                    4th & Washington
# 739729                   Fairmount & Ridge
# 739730                    4th & Washington
# 739731  18th & Washington, Chew Playground
# 739732  18th & Washington, Chew Playground
# 739733                       40th & Spruce
# 739734                         2nd & South
# 739735                Moyamensing & Tasker
# 739736                Moyamensing & Tasker
# 739737                         2nd & South
# 739738                Moyamensing & Tasker
# 739739                      12th & Filbert
# 739740                         17th & Pine
# 739741                       13th & Locust
# 739742                      12th & Filbert
# 739743                    Race Street Pier
# 739744                 9th & Spring Garden
# 739745                 19th & Girard, PTTI
# 739746               Point Breeze & Tasker
# 739747                       13th & Locust
# 739748                 26th & Pennsylvania
# 739749                 26th & Pennsylvania
# 739750                        23rd & South
# 739751              11th & Pine, Kahn Park
# 739752                        23rd & South
# 739753                       15th & Spruce
# 739754                        2nd & Market
#
# [739755 rows x 17 columns]

# %%
# Plot start station usage
df_temp = pd.DataFrame(df_trips.groupby(['Start Hub Name']).size(), columns=['count'])
df_temp = pd.DataFrame(df_temp.sort_values(by="count", ascending=False).head(30))
df_temp.sort_values('count', inplace=True)

fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_temp['count'], y=df_temp.index, ax=ax);
ax.set_xlabel("Number of trips")
ax.set_title("Number of trips from top 30 hubs");

# %%
# Plot start station usage
df_temp = pd.DataFrame(df_trips.groupby(['End Hub Name']).size(), columns=['count'])
df_temp = pd.DataFrame(df_temp.sort_values(by="count", ascending=False).head(30))
df_temp.sort_values('count', inplace=True)

fig, ax = plt.subplots(figsize=(18, 10))
sns.barplot(x=df_temp['count'], y=df_temp.index, ax=ax);
ax.set_xlabel("Number of trips")
ax.set_title("Number of trips to top 30 hubs");

# %% [markdown]
# <hr>
# <a name="plot_weather"> </a>
# ## <span style='color:#3b748a'>VI. Plot weather and daylight data.</span>

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['temp_avg'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Avg Temperature (F)")
ax.set_title("Daily Average Termperatures in " + city_name);

# %%
# Distribution of avg temperatures per day
ax = sns.distplot(df['temp_avg'], color=color_dist)
ax.set_title("Distribution of average daily temperature in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['prec'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Precipitation (inches)")
ax.set_title("Daily Precipitation in " + city_name);

# %%
# Distribution of avg precipitation per day
ax = sns.distplot(df['prec'], color=color_dist)
ax.set_title("Distribution of average precipitation in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=df['Day'], y=df['prec'], ax=ax);
ax.set_xlabel("Day of week")
ax.set_title("Avg Precipitation");

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['wind_avg'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Avg Wind Speed (mph)")
ax.set_title("Daily Average Wind Speed in " + city_name);

# %%
# Distribution of avg wind speeds per day
ax = sns.distplot(df['wind_avg'], color=color_dist)
ax.set_title("Distribution of average wind speeds in " + city_name);
# Out:
# /Users/gwyneth/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Start Date'], df['Daylight'], color=color_line);
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Daylight minutes")
ax.set_title("Daily daylight in " + city_name);

# %% [markdown]
# <hr>
# <a name="corr"></a>
#
# ## <span style='color:#3b748a'>VII. Plot correlations.</span>

# %%
# Feature engineering
peak = 220
df['Peak'] = np.minimum(abs(df['DayOfYear'] - peak), abs(365+peak-df['DayOfYear']))

# %%
df_corr = df[['Trips', 'hum_avg', 'prec', 'temp_avg',
       'wind_avg', 'Peak', 'Daylight', 'Date', 'Day', 'DayOfYear', 'Week', 'Month',
       'Year']].copy()

# %%
# What features are highly correlated with # of trips?
df_corr.corr().sort_values(by="Trips", ascending = True)
# Out:
#               Trips   hum_avg      prec  temp_avg  wind_avg      Peak  \
# Peak      -0.792090 -0.165308 -0.023042 -0.859195  0.294577  1.000000
# Year      -0.446537 -0.058576  0.042732 -0.317094  0.215788  0.574449
# Date      -0.392284 -0.059838 -0.004836 -0.290018  0.183869  0.456569
# wind_avg  -0.344678 -0.163949  0.097995 -0.311528  1.000000  0.294577
# prec      -0.188387  0.371096  1.000000  0.077952  0.097995 -0.023042
# hum_avg    0.015327  1.000000  0.371096  0.280847 -0.163949 -0.165308
# Day        0.058518 -0.066000 -0.026307  0.021979  0.040132 -0.005638
# DayOfYear  0.381118  0.041616 -0.078849  0.259189 -0.189876 -0.538376
# Month      0.382415  0.045185 -0.076148  0.259035 -0.186619 -0.540316
# Week       0.384633  0.041751 -0.079743  0.258751 -0.189753 -0.537777
# Daylight   0.528253  0.136844  0.073982  0.749735 -0.155667 -0.686948
# temp_avg   0.804413  0.280847  0.077952  1.000000 -0.311528 -0.859195
# Trips      1.000000  0.015327 -0.188387  0.804413 -0.344678 -0.792090
#
#            Daylight      Date       Day  DayOfYear      Week     Month  \
# Peak      -0.686948  0.456569 -0.005638  -0.538376 -0.537777 -0.540316
# Year       0.160160  0.865999  0.004136  -0.865999 -0.864753 -0.868088
# Date       0.128620  1.000000  0.011811  -0.499910 -0.497935 -0.507023
# wind_avg  -0.155667  0.183869  0.040132  -0.189876 -0.189753 -0.186619
# prec       0.073982 -0.004836 -0.026307  -0.078849 -0.079743 -0.076148
# hum_avg    0.136844 -0.059838 -0.066000   0.041616  0.041751  0.045185
# Day        0.005823  0.011811  1.000000   0.004646 -0.000136  0.004530
# DayOfYear -0.148778 -0.499910  0.004646   1.000000  0.999816  0.996504
# Month     -0.145391 -0.507023  0.004530   0.996504  0.996270  1.000000
# Week      -0.148729 -0.497935 -0.000136   0.999816  1.000000  0.996270
# Daylight   1.000000  0.128620  0.005823  -0.148778 -0.148729 -0.145391
# temp_avg   0.749735 -0.290018  0.021979   0.259189  0.258751  0.259035
# Trips      0.528253 -0.392284  0.058518   0.381118  0.384633  0.382415
#
#                Year
# Peak       0.574449
# Year       1.000000
# Date       0.865999
# wind_avg   0.215788
# prec       0.042732
# hum_avg   -0.058576
# Day        0.004136
# DayOfYear -0.865999
# Month     -0.868088
# Week      -0.864753
# Daylight   0.160160
# temp_avg  -0.317094
# Trips     -0.446537

# %%
colors_heat = ['#37535e','#3b748a', '#4095b5', '#52aec9', '#72bfc4', '#93d0bf', '#c5e5eaff', 
               '#c5e5eaff', '#93d0bf', '#72bfc4', '#52aec9', '#4095b5', '#3b748a'  
               ]

plt.figure(figsize=(10,10))
ax = sns.heatmap(df_corr.corr().abs(),
            vmin=-1,vmax=1,  cmap = colors_heat, annot=True)
ax.set_title("Feature correlations for " + city_name);

# %% [markdown]
# ### <span style='color:#4095b5'>Scatterplots</span>

# %%
sns.regplot(x=df['Week'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Week")
ax.set_ylabel("Trips")
ax.set_title("Week vs number of trips in " + city_name);

# %%
sns.regplot(x=df['Date'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Date")
ax.set_ylabel("Trips")
ax.set_title("Date vs number of trips in " + city_name);

# %%
sns.regplot(x=df['DayOfYear'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Day of Year")
ax.set_ylabel("Trips")
ax.set_title("Day of year vs number of trips in " + city_name);

# %%
peak = 220
df['Peak'] = np.minimum(abs(df['DayOfYear'] - peak), abs(365+peak-df['DayOfYear']))

sns.regplot(x=df['Peak'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Days from Peak")
ax.set_ylabel("Trips")
ax.set_title("Days from peak vs number of trips in " + city_name);

# %%
sns.regplot(x=df['Peak'], y=np.log(df["Trips"]), color=color_reg)
ax = plt.gca()
ax.set_xlabel("Days from Peak")
ax.set_ylabel("log(Trips)")
ax.set_title("Days from peak vs log of number of trips in " + city_name);

# %%
sns.regplot(x=df['Daylight'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Daylight")
ax.set_ylabel("Trips")
ax.set_title("Daylight vs number of trips in " + city_name);

# %%
sns.regplot(x=df['prec'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Precipitation (in)")
ax.set_ylabel("Trips")
ax.set_title("Precipitation vs number of trips in " + city_name);

# %%
sns.regplot(x=df['temp_avg'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Temperature")
ax.set_ylabel("Trips")
ax.set_title("Temperature vs number of trips in " + city_name);

# %%
sns.regplot(x=df['temp_avg']/(df['prec']+.01), y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Temperature/Preipitation")
ax.set_ylabel("Trips")
ax.set_title("Temperature/Preipitation vs number of trips in " + city_name);

# %%
sns.regplot(x=df['wind_avg'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Wind speed")
ax.set_ylabel("Trips")
ax.set_title("Wind speed vs number of trips in " + city_name);

# %%
sns.regplot(x=df['hum_avg'], y=df["Trips"], color=color_reg)
ax = plt.gca()
ax.set_xlabel("Humidity")
ax.set_ylabel("Trips")
ax.set_title("Humidity vs number of trips in " + city_name);

# %% [markdown]
# <hr>
# <a name="future"></a>
#
# ## <span style='color:#3b748a'>VIII. Further work.</span>

# %% [markdown]
# * Bike data
# * Time of day
# * Cumulative usage
# * Hub usage
# * Lat/Long improvements

# %% [markdown]
# <hr>
# <a name="store"></a>
#
# ## <span style='color:#3b748a'>IX. For future reference.</span>
